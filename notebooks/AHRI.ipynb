# %% [markdown]
# RDFLow
# ========================
# An implementation of the RDFlow pipeline for the documentation and visualization of constantly evolving RDF datasets.
#
# # Data

# %%
# %run ../extract_schema.py ../schemas/AHRI ../data/AHRI/combined_data_updated.ttl
# Out:
# 02/10/2025 14:05:52 -- Starting instance tracker...
# sheXer version: 2.6.5.1
# 02/10/2025 14:06:21 -- Instance tracker finished. 160999 instances located
# 02/10/2025 14:06:21 -- Starting class profiler...
# 02/10/2025 14:06:21 -- Instance counts completed. Annotating instance features...
# 02/10/2025 14:06:58 -- Instance features annotated. Number of relevant triples computed: 960383. Building shape profiles...
# 02/10/2025 14:06:59 -- Draft shape profiles built. Cleaning shape profiles...
# 02/10/2025 14:06:59 -- Shape profiles done. Working with 14 shapes.
# 02/10/2025 14:06:59 -- Detecting example features for each shape...
# 02/10/2025 14:07:00 -- Mimimal IRIs detected...
# 02/10/2025 14:07:00 -- Starting shape extraction...
# 02/10/2025 14:07:00 -- Shape drafts built. Sorting constraints...
# 02/10/2025 14:07:00 -- Constraints sorted. Adjusting cardinalities...
# 02/10/2025 14:07:00 -- Cardinalities adjusted. Cleaning empty shapes if needed...
# ...

# %%
# !docker run --rm -it  -v /Users/andra/project/RDFlow:/config  dbcls/rdf-config:latest  rdf-config --config /config/schemas/AHRI --schema >/Users/andra/project/RDFlow/schemas/AHRI/rdf-config-schema.svg
# Out:
# WARNING: The requested image's platform (linux/amd64) does not match the detected host platform (linux/arm64/v8) and no specific platform was requested
